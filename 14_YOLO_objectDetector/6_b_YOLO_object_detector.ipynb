# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import cvlib as cv # pip install cvlib
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread(r'C:\Users\Abdul Samad\Downloads\fr\Code and Data\12_Object_Detection\images\p2.jpeg')

# %%
plt.imshow(im[:,:,::-1])

# %%
bbox , conf = cv.detect_face(im)

# %%
bbox
# Out:
# [[322, 75, 357, 111],
#  [178, 93, 211, 131],
#  [12, 67, 47, 107],
#  [411, 56, 446, 96],
#  [268, 103, 297, 140],
#  [104, 37, 137, 72]]

# %%
conf
# Out:
# [0.97767776, 0.9749801, 0.95556337, 0.89820945, 0.8287019, 0.7974265]

# %%
labels = []
for i in range(len(conf)):
    labels.append('person')

# %%
im2 = draw_bbox(im,bbox,labels,conf)
plt.imshow(im2[:,:,::-1])

# %%
im = cv2.imread(r'C:\Users\Abdul Samad\Downloads\fr\Code and Data\12_Object_Detection\images\p.jpg')
bbox , labels , conf = cv.detect_common_objects(im)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-31a60e2dbee6> in <module>
#       1 im = cv2.imread(r'C:\Users\Abdul Samad\Downloads\fr\Code and Data\12_Object_Detection\images\p.jpg')
# ----> 2 bbox , labels , conf = cv.detect_common_objects(im)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvlib\object_detection.py in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#     133     net.setInput(blob)
#     134
# --> 135     outs = net.forward(get_output_layers(net))
#     136
#     137     class_ids = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\cvlib\object_detection.py in get_output_layers(net)
#      27     layer_names = net.getLayerNames()
#      28
# ---> 29     output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
#      30
#      31     return output_layers
#
# ...

# %%
im2 = draw_bbox(im,bbox,labels,conf)
plt.imshow(im2[:,:,::-1])

# %%
labels
# Out:
# ['person', 'person', 'person', 'person', 'person', 'person']
